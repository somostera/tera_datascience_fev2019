# %% [markdown]
# # Bem vindos à aula mais fofinha e mais legal de todas!

# %% [markdown]
# ### SIM!!! uma aula todinha sobre PANDAS!

# %% [markdown]
# ![tenor%20%283%29.gif](attachment:tenor%20%283%29.gif)

# %% [markdown]
# Pandas é um pacote construido com a base de NumPy, e provê uma implementação eficiente para DataFrames. DataFrames são essencialmente matrizes multidimensionais com rótulos de colunas e linhas. A maioria das vezes é composta por tipos heterogêneos de dados e dados faltantes.
#
# Além de oferecer uma interface de armazenamento conveniente para dados rotulados, o Pandas implementa várias operações de dados poderosas, familiares aos usuários de estruturas de bancos de dados e programas de planilhas.
#
# Como vimos, a estrutura de dados ndarray do NumPy fornece recursos essenciais para o tipo de dados limpos e bem organizados normalmente vistos em tarefas de computação numérica.
# Embora sirva a esse propósito muito bem, suas limitações tornam-se claras quando precisamos de mais flexibilidade (por exemplo, anexar rótulos a dados, trabalhar com dados ausentes, etc.) e ao tentar operações que não mapeiam bem a transmissão elementar (por exemplo, agrupamentos, pivôs, etc.), cada um dos quais é uma parte importante da análise dos dados menos estruturados disponíveis em muitas formas no mundo ao nosso redor.
#
# O pandas, e em particular seus objetos Series e DataFrame, se baseiam na estrutura do array NumPy e fornecem acesso eficiente a esses tipos de tarefas de "coleta de dados" que ocupam muito do tempo de um cientista de dados.

# %%
import pandas
pandas.__version__
# Out:
# '0.23.4'

# %% [markdown]
# #### normalmente instalamos o panda e colocamos um 'apelido' nele de pd
# Nota: Quando você adiciona o as pd no final de sua declaração de importação, seu Notebook Jupyter entende que, a partir deste ponto, toda vez que você digitar pd, você está realmente se referindo à biblioteca de pandas.

# %%
import pandas as pd

# %%
#socorro!!! não estou entendendo nada desse cara!
pd?

# %% [markdown]
# ![tenor.gif](attachment:tenor.gif)

# %% [markdown]
# Podemos usar informações para o pandas de várias fontes, importar um .csv, criar dicionários, importar tabelas SQL, ou mesmo arquivos excel.
#
# Mas o objetivo é sempre o mesmo, se queremos analisar dados com pandas, a primiera coisa a se fazer é ler um arquivo compatível com pandas.

# %%
#criando um dataframe de dicionário
area = pd.Series({'California': 423967, 'Texas': 695662,
                  'New York': 141297, 'Florida': 170312,
                  'Illinois': 149995})
pop = pd.Series({'California': 38332521, 'Texas': 26448193,
                 'New York': 19651127, 'Florida': 19552860,
                 'Illinois': 12882135})
data = pd.DataFrame({'area':area, 'pop':pop})
data
# Out:
#               area       pop
# California  423967  38332521
# Texas       695662  26448193
# New York    141297  19651127
# Florida     170312  19552860
# Illinois    149995  12882135

# %%
#importarnto um arquivo .csv
df = pd.read_csv('departments.csv')
df
# Out:
#     department_id       department
# 0               1           frozen
# 1               2            other
# 2               3           bakery
# 3               4          produce
# 4               5          alcohol
# 5               6    international
# 6               7        beverages
# 7               8             pets
# 8               9  dry goods pasta
# 9              10             bulk
# 10             11    personal care
# 11             12     meat seafood
# 12             13           pantry
# 13             14        breakfast
# 14             15     canned goods
# 15             16       dairy eggs
# 16             17        household
# 17             18           babies
# 18             19           snacks
# 19             20             deli
# 20             21          missing

# %% [markdown]
# ### Mas qual a diferença entre séries e dataframes?

# %% [markdown]
# Podemos entender séries como uma matriz rotulada de 1 dimensão. Você pode acessar elementos individuais desta série por meio desses rótulos.
#
# Um dataframe é semelhante à pasta de trabalho do Excel - você tem nomes de coluna referentes a colunas e você tem linhas, que podem ser acessadas com o uso de números de linha.
# A diferença essencial é que os nomes de coluna e os números de linha são conhecidos como índice de coluna e linha, no caso de quadros de dados.
#
# Séries e dataframes formam o modelo de dados centrais para Pandas em Python. Os conjuntos de dados são primeiro lidos nestes quadros de dados e então várias operações (por exemplo, agrupar por, agregação, etc.) podem ser aplicadas com muita facilidade a suas colunas.
#
# Ou seja: os objetos Series e DataFrame contêm um índice explícito que permite fazer referência e modificar dados.

# %%
ind = pd.Index([2, 3, 5, 7, 11])
ind
# Out:
# Int64Index([2, 3, 5, 7, 11], dtype='int64')

# %%
ind[1]
# Out:
# 3

# %%
ind[::2]
# Out:
# Int64Index([2, 5, 11], dtype='int64')

# %%
#ainda trazemos muitos atributos de NumPy
print(ind.size, ind.shape, ind.ndim, ind.dtype)
# Out:
# 5 (5,) 1 int64

# %%
# a maior diferença é que os índices são imutáveis
ind[1] = 0
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-d4aa115dac39> in <module>
#       1 # a maior diferença é que os índices são imutáveis
# ----> 2 ind[1] = 0
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in __setitem__(self, key, value)
#    2063
#    2064     def __setitem__(self, key, value):
# -> 2065         raise TypeError("Index does not support mutable operations")
#    2066
#    2067     def __getitem__(self, key):
#
# TypeError: Index does not support mutable operations

# %% [markdown]
#  Esssa imutabilidade torna mais seguro compartilhar indices entre multiplos dataframes e matrizes.

# %% [markdown]
# ![tenor%20%281%29.gif](attachment:tenor%20%281%29.gif)

# %% [markdown]
# ## vamos colocar a mão na massa!
